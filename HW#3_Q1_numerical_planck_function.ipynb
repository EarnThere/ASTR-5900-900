# %%
import matplotlib.pyplot as plt
import numpy as np

h = 6.626e-34
c = 3.0e+8
k = 1.38e-23

def planck(wav, T):
    a = 2.0*h*c**2
    b = h*c/(wav*k*T)
    intensity = a/ ( (wav**5) * (np.exp(b) - 1.0) )
    return intensity

# starting at 1 nm to avoid wav = 0, which would result in division by zero.
wavelengths = np.arange(1e-9, 4e-6, 1e-9) 
x=wavelengths*1e9
# intensity at 4000K, 5000K, 6000K, 7000K
intensity5000 = planck(wavelengths, 5000.)
intensity10000 = planck(wavelengths, 10000.)
intensity20000 = planck(wavelengths, 20000.)

plt.figure(figsize=(10,30))
plt.style.use('seaborn-darkgrid')
plt.xlabel('Wavelenght (nm)')
plt.ylabel('Intensity')

plt.subplot(3,1,1)
plt.plot(x, intensity5000, 'r-', label='5000 K') 
plt.axhline(color='k')
plt.axvline(x=364, color='k', linestyle='--', label='364 nm')
plt.fill_between(x, intensity5000, where=[(x > 0) and (x < 364) for x in x])
plt.legend(loc='best')

plt.subplot(3,1,2)
plt.plot(x, intensity10000, 'g-', label='10000 K')
plt.axhline(color='k')
plt.axvline(x=364, color='k', linestyle='--', label='364 nm')
plt.fill_between(x, intensity10000, where=[(x > 0) and (x < 364) for x in x])
plt.legend(loc='best')

plt.subplot(3,1,3)
plt.plot(x, intensity20000, 'b-', label='20000 K')
plt.axhline(color='k')
plt.axvline(x=364, color='k', linestyle='--', label='364 nm')
plt.fill_between(x, intensity20000, where=[(x > 0) and (x < 364) for x in x])
plt.legend(loc='best')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: RuntimeWarning: overflow encountered in exp
#   # This is added back by InteractiveShellApp.init_path()

# %%
print(intensity5000[:364].sum()/intensity5000.sum())
print(intensity10000[:364].sum()/intensity10000.sum())
print(intensity20000[:364].sum()/intensity20000.sum())
# Out:
# 0.04240470100630404
# 0.41275409475054214
# 0.8237127489241595

# %%
plt.plot(1-A^2/B^2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-fb352dc2f84d> in <module>()
# ----> 1 plt.plot(1-A^2/B^2)
#
# NameError: name 'A' is not defined
